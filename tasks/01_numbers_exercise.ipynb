# %% [markdown]
# # Лабораторная работа 1

# %% [markdown]
# ## 1. Классическая первая программа
# Запустите её.

# %%
print('Hello world!')

# %% [markdown]
# ## 2. Синтаксис функции
# Напишите следующую математическую формулу на языке Python:
#
# \begin{align}
#  result = 6a^3 - \frac{8b^2 }{4c} + 11
# \end{align}

# %%
a = 2
b = 3
c = 2

# %%
# Ваша формула тут:
result =

# %%
assert result == 50

# %% [markdown]
# ## 3. Ввод с клавиатуры

# %%
f_name = input('Enter your first name:')
l_name = input('Enter your last name:')
print(f_name, l_name)

# %% [markdown]
# ## 4. Простейшее приветствие
# Попросите пользователя ввести имя. Напечатайте "Привет <ИМЯ>"

# %% [markdown]
# ##5. Работа с числами
# Для введённого с клавиатуры числа(например 2026) выведите строку следующего вида "Вы ввели число 2026, в нём 4 цифры, последняя из которых равна 6".

# %%
# Подключаем математические функции
import math

# Считываем число с клавиатуры и преобразуем его как целое число
num = int(input("Введите число: "))

# Поиск последней цифры. Посказка, остаток деления - `%`
last_digit = # Ваш код тут

# Поиск количества цифр. Посказка, логарифм - `math.log10(...)`
digits_count = # Ваш код тут

# Простой вывод через запятую
print("Вы ввели число", num, ", в нём", digits_count, "цифры, последняя из которых равна", last_digit)
# Out:
# Введите число: 2026
# Вы ввели число 2026 , в нём 4.306639441024261 цифры, последняя из которых равна 6

# %% [markdown]
# ## 6. Недостатки операций с плавающей запятой
# Докажите что `0.1 + 0.2 == 0.3`

# %%
# Ваше решение

# Так не работает:
# assert 0.1 + 0.2 == 0.3
